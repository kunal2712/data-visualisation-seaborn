# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Python310\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fifa_filepath = "../Visualization/fifa.csv"

fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %%
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# LINE-PLOT

# %%
plt.figure(figsize=(16,6))

sns.lineplot(data=fifa_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# #bar-graph 
# sns.barplot(data=fifa_data)

# %%
spotify_file_path = "../Visualization/spotify.csv"
spotify_data = pd.read_csv(spotify_file_path, index_col="Date", parse_dates=True)

# %%
spotify_data.head()
#spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(14,6)) #setting the size 

plt.title("Daily Global Streams of hit singles") #adding the title

sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:title={'center':'Daily Global Streams of hit singles'}, xlabel='Date'>

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %% [markdown]
# Plotting particular columns

# %%
plt.figure(figsize=(14,6))

plt.title("Streams of two popular singles")

sns.lineplot(data=spotify_data['HUMBLE.'], label="HUMBLE.")

sns.lineplot(data=spotify_data['Unforgettable'], label="Unforgettable.")
# Out:
# <AxesSubplot:title={'center':'Streams of two popular singles'}, xlabel='Date', ylabel='HUMBLE.'>

# %% [markdown]
# BAR-GRAPH

# %%
flight_delays = pd.read_csv('flight_delays.csv', index_col='Month')

plt.figure(figsize=(14,7))
plt.title("Average flight delays of NK ")


sns.barplot(x=flight_delays.index, y=flight_delays['NK']) # horizontal : index values , vertical : single column values
plt.ylabel("Arrival delay of NK (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay of NK (in minutes)')

# %% [markdown]
# HEAT-MAP

# %%
plt.figure(figsize=(14,7))
sns.heatmap(data=flight_delays , annot=True)
plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %% [markdown]
# SCATTER-PLOT : To check correlation between any attribute and target values

# %%
insurance_data = pd.read_csv('insurance.csv')
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Lets check the correlation between 'bmi' and 'charges' (target)

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(x = insurance_data['bmi'] , y = insurance_data['charges'])
plt.xlabel('Body Mass Index')
plt.ylabel('Insurance Charges')
# Out:
# Text(0, 0.5, 'Insurance Charges')

# %% [markdown]
# The scatterplot above suggests that body mass index (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)
#
# To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to sns.regplot.

# %%
plt.figure(figsize=(12,7))
sns.regplot(x = insurance_data['bmi'] , y = insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Color-coded scatter plots
#
# We can use scatter plots to display the relationships between (not two, but...) three variables! One way of doing this is by color-coding the points.
#
# For instance, to understand how smoking affects the relationship between BMI and insurance costs, we can color-code the points by 'smoker', and plot the other two columns ('bmi', 'charges') on the axes.

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x=insurance_data['bmi'] , y = insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# This scatter plot shows that while nonsmokers to tend to pay slightly more with increasing BMI, smokers pay MUCH more.
#
# To further emphasize this fact, we can use the sns.lmplot command to add two regression lines, corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
plt.figure(figsize=(15,9))
sns.lmplot(x='bmi' , y='charges' ,hue='smoker' , data=insurance_data) #different way of passing parameters

# %% [markdown]
# Swarm-Plot (Categorial) : used to visualize relation between categorial and numerical columns

# %%
plt.figure(figsize=(12,7))

sns.swarmplot(x=insurance_data['smoker'], y = insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>
# c:\Python310\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Among other things, this plot shows us that:
#
# on average, non-smokers are charged less than smokers, and
# the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.

# %%
iris_data = pd.read_csv('iris.csv', index_col='Id')
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# Histogram : To visualize the distribution of various samples over a particular attribute

# %%
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# DensityPlot  : A smoothed histogram

# %%
sns.kdeplot(iris_data['Petal Length (cm)'], fill=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# 2d KDE plot : For multiple attributes

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'] , y = iris_data['Sepal Width (cm)'] , kind='kde')

# %% [markdown]
# * The curve at the top of the figure is a KDE plot for the data on the x-axis (in this case, iris_data['Petal Length (cm)']), and
#
# * The curve on the right of the figure is a KDE plot for the data on the y-axis (in this case, iris_data['Sepal Width (cm)']).

# %% [markdown]
# Color-coded plots
#
# * data= provides the name of the variable that we used to read in the data
# * x= sets the name of column with the data we want to plot
# * hue= sets the column we'll use to split the data into different histograms

# %%
plt.figure(figsize=(12,7))
sns.histplot(data=iris_data, x = 'Petal Length (cm)' , hue= 'Species')

plt.title("Histogram of Petal length, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal length, by Species')

# %% [markdown]
# Color-coded smoothed plot

# %%
plt.figure(figsize=(12,7))
sns.kdeplot(data=iris_data, x = 'Petal Length (cm)' , hue= 'Species', fill=True)

plt.title("Histogram of Petal length, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal length, by Species')

# %% [markdown]
# Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks", and you need only use a command similar to the one in the code cell above (with the chosen theme filled in) to change it.

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(12,7))
sns.kdeplot(data=iris_data, x = 'Petal Length (cm)' , hue= 'Species', fill=True)

plt.title("Histogram of Petal length, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal length, by Species')
